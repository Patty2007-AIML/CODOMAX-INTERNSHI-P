# %%
import pandas as pd

df = pd.read_csv("exam_score_predictions.csv")

print("Missing Values Before Cleaning:")
print(df.isnull().sum())

print("Duplicate Rows Before Cleaning:", df.duplicated().sum())

df = df.dropna()
df = df.drop_duplicates()

print("\nDataset Statistics:")
print(df.describe())

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())

print("Duplicate Rows After Cleaning:", df.duplicated().sum())

df.to_csv("cleaned_exam_score_predictions.csv", index=False)

print("\nCleaned dataset saved successfully")
# Out:
# Missing Values Before Cleaning:
# id            0
# exam_score    0
# dtype: int64
# Duplicate Rows Before Cleaning: 0
#
# Dataset Statistics:
#                   id     exam_score
# count  270000.000000  270000.000000
# mean   764999.500000      62.516507
# std     77942.430678      16.685462
# min    630000.000000      15.134483
# 25%    697499.750000      49.732725
# 50%    764999.500000      62.620928
# 75%    832499.250000      75.300977
# max    899999.000000     110.707032
#
# Missing Values After Cleaning:
# id            0
# exam_score    0
# dtype: int64
# Duplicate Rows After Cleaning: 0
#
# Cleaned dataset saved successfully
